# %%
import pandas as pd
import numpy as np

# %%
df = dataframes = pd.read_csv("insurance_data.csv")

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df.head(5)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.isnull().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# age                 0.0
# bought_insurance    0.0
# dtype: float64

# %%
a = df.isnull().sum()/len(df)*100

# %%
variables = df.columns

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corr = df.corr()
plt.figure(figsize = (10,6))
sns.heatmap(corr, annot = True)
plt.show()
